# %%
import pandas as pd

# %% [markdown]
# #### TRANSFORM .PARQUET INTO .CSV FILE

# %%
df = pd.read_parquet('yellow_tripdata_2021-01.parquet', engine='pyarrow')

# %%
df.to_csv('yellow_tripdata_2021-01.csv', index=False)

# %% [markdown]
# #### CREATE ENGINE TO CONECT INTO POSTGRESQL SERVER

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://db_test:010203@localhost:5432/ny_taxi_test')

# %% [markdown]
# #### DATAFRAME ITERATOR AND COLUMN TYPES

# %%
df_iter = pd.read_csv('output.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %% [markdown]
# #### CREATE SQL TABLE COLUMNS AND FIRST CHUNKSIZE

# %%
df.head(n=0).to_sql(name='ny_taxi_test', con=engine, if_exists='replace')

# %%
df.to_sql(name='ny_taxi_test', con=engine, if_exists='append')

# %% [markdown]
# #### ITERATOR

# %%
while True:
    try:
        df_novo = next(df_iter)
        df_novo['tpep_pickup_datetime'] = pd.to_datetime(df_novo['tpep_pickup_datetime'])
        df_novo['tpep_dropoff_datetime'] = pd.to_datetime(df_novo['tpep_dropoff_datetime'])
        df_novo.to_sql(name='ny_taxi_test', con=engine, if_exists='append')
        print('inserted another chunck ...')

    except StopIteration:
        print('Done')
        break
# Out:
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# /home/felipe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3377: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# inserted another chunck ...
# inserted another chunck ...
# ...

# %%
df_2 = pd.read_csv('yellow_tripdata_2021-01.csv')

# %%
df_2.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df = pd.read_csv('yellow.csv')

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# airport_fee              float64
# dtype: object

# %%
###COMO TORNAR UM CSV EM SQL SEM PRECISAR CRIAR OS TIPOS DE TABELA

# %%
print(pd.io.sql.get_schema(df, name='yellowtaxi_data_january2021'))
# Out:
# CREATE TABLE "yellowtaxi_data_january2021" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
engine = create_engine('postgresql://db_test:010203@localhost:5432/ny_taxi_test')

# %%
print(pd.io.sql.get_schema(df, name='yellowtaxi_data_january2021', con = engine))
# Out:
# CREATE TABLE yellowtaxi_data_january2021 (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
##COLOCAR TODO O DATASET JUNTO

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv')
# Out:
# /home/felipe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
len(df_part1)
# Out:
# 100000

# %%
df_part1['tpep_pickup_datetime'] = pd.to_datetime(df_part1['tpep_pickup_datetime'])
df_part1['tpep_dropoff_datetime'] = pd.to_datetime(df_part1['tpep_dropoff_datetime'])

# %%
df_part1.head(0).to_sql(name='ny_taxi_test', con=engine, if_exists='replace')

# %%
df_part1.to_sql(name='ny_taxi_test', con=engine, if_exists='append')

# %%
while True:
    df_novo = next(df)
    df_novo['tpep_pickup_datetime'] = pd.to_datetime(df_novo['tpep_pickup_datetime'])
    df_novo['tpep_dropoff_datetime'] = pd.to_datetime(df_novo['tpep_dropoff_datetime'])
    df_novo.to_sql(name='ny_taxi_test', con=engine, if_exists='append')
    print('inserted another chunck ...')
# Out:
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# inserted another chunck ...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_2010/3729393545.py in <module>
#       1 while True:
# ----> 2     df_novo = next(df)
#       3     df_novo['tpep_pickup_datetime'] = pd.to_datetime(df_novo['tpep_pickup_datetime'])
#       4     df_novo['tpep_dropoff_datetime'] = pd.to_datetime(df_novo['tpep_dropoff_datetime'])
#       5     df_novo.to_sql(name='ny_taxi_test', con=engine, if_exists='append')
#
# ...
