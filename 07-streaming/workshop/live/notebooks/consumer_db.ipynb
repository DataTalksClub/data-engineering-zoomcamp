# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

# %%
from models import Ride, ride_deserializer

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-database',
    value_deserializer=ride_deserializer
)

# %%
import psycopg2

conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)

conn.autocommit = True
cur = conn.cursor()

# %%
from datetime import datetime

print(f"Listening to {topic_name} and writing to PostgreSQL...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
    cur.execute(
        """INSERT INTO processed_events
           (PULocationID, DOLocationID, trip_distance, total_amount, pickup_datetime)
           VALUES (%s, %s, %s, %s, %s)""",
        (ride.PULocationID, ride.DOLocationID,
         ride.trip_distance, ride.total_amount, pickup_dt)
    )
    count += 1
    if count % 100 == 0:
        print(f"Inserted {count} rows...")

consumer.close()
cur.close()
conn.close()
# Out:
# Listening to rides and writing to PostgreSQL...
# Inserted 100 rows...
# Inserted 200 rows...
# Inserted 300 rows...
# Inserted 400 rows...
# Inserted 500 rows...
# Inserted 600 rows...
# Inserted 700 rows...
# Inserted 800 rows...
# Inserted 900 rows...
# Inserted 1000 rows...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 print(f"Listening to {topic_name} and writing to PostgreSQL...")
#       5 count = 0
# ----> 6 for message in consumer:
#       7     ride = message.value
#       8     pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/client_async.py:781, in KafkaClient._poll(self, timeout)
#     778         continue
#     780     self._idle_expiry_manager.update(conn.node_id)
# --> 781     self._pending_completion.extend(conn.recv())
#     783 # Check for additional pending SSL bytes
#     784 if self.config['security_protocol'] in ('SSL', 'SASL_SSL'):
#     785     # TODO: optimize
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/conn.py:1131, in BrokerConnection.recv(self)
#    1126 def recv(self):
#    1127     """Non-blocking network receive.
#    1128
#    1129     Return list of (response, future) tuples
#    1130     """
# -> 1131     responses = self._recv()
#    1132     if not responses and self.requests_timed_out():
#    1133         timed_out = self.timed_out_ifrs()
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/conn.py:1202, in BrokerConnection._recv(self)
#    1200 recvd_data = b''.join(recvd)
#    1201 if self._sensors:
# -> 1202     self._sensors.bytes_received.record(len(recvd_data))
#    1204 # We need to keep the lock through protocol receipt
#    1205 # so that we ensure that the processed byte order is the
#    1206 # same as the received byte order
#    1207 try:
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/metrics/stats/sensor.py:77, in Sensor.record(self, value, time_ms)
#      74 with self._lock:  # XXX high volume, might be performance issue
#      75     # increment all the stats
#      76     for stat in self._stats:
# ---> 77         stat.record(self._config, value, time_ms)
#      78     self._check_quotas(time_ms)
#      79 for parent in self._parents:
#
# File /workspaces/streaming-workshop/.venv/lib/python3.12/site-packages/kafka/metrics/stats/rate.py:49, in Rate.record(self, config, value, time_ms)
#      46 def unit_name(self):
#      47     return TimeUnit.get_name(self._unit)
# ---> 49 def record(self, config, value, time_ms):
#      50     self._stat.record(config, value, time_ms)
#      52 def measure(self, config, now):
#
# KeyboardInterrupt:
